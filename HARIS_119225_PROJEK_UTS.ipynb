# %% [markdown]
# <a href="https://colab.research.google.com/github/hrswps/hrswps.github.io/blob/main/HARIS_119225_PROJEK_UTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TUGAS UTS STRUKTUR DATA SERTU HARIS D3 XVI TEKNIK INFORMATIKA
import sys

def menu1():
    ''' Pilih Item Dari Menu '''
    
    chosen_element = 0;
    
    print("#############################################################################")
    print("########                                                             ########")
    print("########                   Projek UTS Struktur Data                  ########")
    print("######## ----------------------------------------------------------- ########")
    print("########          Nama        :   Haris Wiyansah Pasorong            ########")
    print("########          Pangkat/NRP :   Sertu SBA NRP 119225               ########")
    print("########          Prodi       :   D3 XVI Teknik Informatika          ########")
    print("######## ----------------------------------------------------------- ########")
    print("########                      Menu Pilihan Utama                     ########")
    print("########          [1] Linked List                                    ########")
    print("########          [2] Queue                                          ########")
    print("########          [3] Rekursif                                       ########")
    print("########          [4] Masukkan Pilihan Anda                          ########")
    print("########          [5] Kembali Ke Menu Pilihan Utama                  ########")
    print("########          [6] Keluar                                         ########")
    print("########                                                             ########")
    print("#############################################################################")
    chosen_element = input("Pilih Menu : ")
    
    if int(chosen_element) == 1:
      class Node:

       def __init__(self):
               self.data = None
               self.next = None

      class LinkedList:

       def __init__(self):
               self.head = None

       def insert(self,data):
               data = input("Masukkan Data:")
               node = Node()
               node.data = data
               node.next = self.head
               self.head = node

       def print(self):
               print_list = self.head
               while print_list:
                       print(print_list.data)
                       print_list = print_list.next

       def size(self):
               i=0
               head = self.head
               while head:
                      i+=1
                      head = head.next
               print (i)


      MyList = LinkedList()

      while True:
       print("#############################################################################")
       print("########                                                             ########")
       print("########                    Program Linked List                      ########")
       print("########-------------------------------------------------------------########")
       print("########                       Menu Pilihan                          ########")
       print("########      [1] Masukkan Data                                      ########")
       print("########      [2] Print Data dan Jumlah Data                         ########")
       print("########      [3] Kembali Ke Menu Pilihan Utama                      ########")
       print("########                                                             ########")
       print("#############################################################################")
       menu = int(input("Pilih Menu :"))

       if menu == 1:
               MyList.insert(1)
               print("Data Linked List Sekarang :")
               MyList.print()
       elif menu == 2:
               print("Data Linked List Sekarang :")
               MyList.print()
               print("Jumlah data Linked List:")
               MyList.size()
       elif menu == 3:
              menu1()
              break
      
    elif int(chosen_element) == 2:
        queue = [ ]
        data = 0 
        while True :
          print("#############################################################################")
          print("########                                                             ########")
          print("########                       Program Queue                         ########")
          print("########-------------------------------------------------------------########")
          print("########                       Menu Pilihan                          ########")
          print("########      [1] Enqueue                                            ########")
          print("########      [2] Dequeue                                            ########")
          print("########      [3] Kembali Ke Menu Pilihan Utama                      ########")
          print("########                                                             ########")
          print("#############################################################################")
          user = input("Pilih Menu : ")
          if user == "1" :
              data = input("Masukkan Data : ")
              queue.append(data)
          elif user == "2" :
              if queue == [ ]:
                  print("UnderFlow")
              else :
                  queue.pop(0)
          elif user == "3" :
            menu1()
            break
          else :
              break
          print("Data Queue Sekarang = ",queue)

    elif int(chosen_element) == 3:

      def faktorial(a):
          if a == 1:
            return (a)
          else:
            return (a*faktorial(a-1))

      bil = int(input("Masukan Bilangan : "))
      print("#############################################################################")
      print("########                      Program Rekursif                       ########")
      print("########-------------------------------------------------------------########")
      print("########                         Faktorial :                         ########")
      print("                                  %d! = %d                                  "% (bil, faktorial(bil)))
      print("#############################################################################")

      def pangkat(x,y):
          if y == 0:
            return 1
          else:
            return x * pangkat(x,y-1)

      x = int(input("Masukan Nilai X : "))
      y = int(input("Masukan Nilai Y : "))

      
      print("########-------------------------------------------------------------########")
      print("########                        Kepangkatan :                        ########")
      print("                          %d dipangkatkan %d = %d                            "% (x,y,pangkat(x,y)))
      print("#############################################################################")

      def fibonacci(n):
          if n == 0 or n == 1:
            return n
          else:
            return (fibonacci(n-1) + fibonacci(n-2))

      x = int(input("Masukan Batas Deret Bilangan Fibonacci : "))
      print("########-------------------------------------------------------------########")
      print("########                      Deret Fibonacci :                      ########")
      for i in range(x):
        print(fibonacci(i),end=' ')
        print()

      menu1()

    elif int(chosen_element) == 4:
        print('Masukkan Pilihan Anda!!!')
        menu1()
    elif int(chosen_element) == 5:
        menu1()
    elif int(chosen_element) == 6:
        print("#############################################################################")
        print("########                                                             ########")
        print('########            TERIMA KASIH TELAH MENGGUNAKAN PROGRAM           ########')
        print('########         Dikerjakan Oleh  :   Haris Wiyansah Pasorong        ########')
        print("########                                                             ########")
        print("#############################################################################")
        sys.exit
    else:
        print('Maaf, Data yang harus di masukkan angka 1-6, coba lagi!')

if __name__ == '__main__':
    ''' Fungsi Utama Dari Script Python '''

    menu1()
